# %%
import pandas

# %%
df = pandas.read_csv("ARROW.csv")

# %%
df
# Out:
#      frequency  Radial Velocity  Intensity  Unnamed: 3  Unnamed: 4
# 0      -800000           168.97      2.412         NaN         NaN
# 1      -795000           167.91      2.378         NaN         NaN
# 2      -790000           166.85      2.344         NaN         NaN
# 3      -785000           165.80      2.344         NaN         NaN
# 4      -780000           164.74      2.324         NaN         NaN
# 5      -775000           163.69      2.327         NaN         NaN
# 6      -770000           162.63      2.341         NaN         NaN
# 7      -765000           161.57      2.334         NaN         NaN
# 8      -760000           160.52      2.354         NaN         NaN
# 9      -755000           159.46      2.393         NaN         NaN
# 10     -750000           158.41      2.383         NaN         NaN
# 11     -745000           157.35      2.363         NaN         NaN
# 12     -740000           156.29      2.358         NaN         NaN
# ...
